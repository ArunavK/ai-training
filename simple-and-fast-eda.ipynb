# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Looking at the data

# %%
df = pd.read_csv("../input/tabular-playground-series-jan-2021/train.csv")
df.head()
# Out:
#    id     cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0   1  0.670390  0.811300  0.643968  0.291791  0.284117  0.855953  0.890700
# 1   3  0.388053  0.621104  0.686102  0.501149  0.643790  0.449805  0.510824
# 2   4  0.834950  0.227436  0.301584  0.293408  0.606839  0.829175  0.506143
# 3   5  0.820708  0.160155  0.546887  0.726104  0.282444  0.785108  0.752758
# 4   8  0.935278  0.421235  0.303801  0.880214  0.665610  0.830131  0.487113
#
#       cont8     cont9    cont10    cont11    cont12    cont13    cont14  \
# 0  0.285542  0.558245  0.779418  0.921832  0.866772  0.878733  0.305411
# 1  0.580748  0.418335  0.432632  0.439872  0.434971  0.369957  0.369484
# 2  0.558771  0.587603  0.823312  0.567007  0.677708  0.882938  0.303047
# 3  0.823267  0.574466  0.580843  0.769594  0.818143  0.914281  0.279528
# 4  0.604157  0.874658  0.863427  0.983575  0.900464  0.935918  0.435772
#
#      target
# 0  7.243043
# 1  8.203331
# 2  7.776091
# 3  6.957716
# ...

# %%
df.describe()
# Out:
#                   id          cont1          cont2          cont3  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   249825.145857       0.506873       0.497898       0.521557
# std    144476.732562       0.203976       0.228159       0.200770
# min         1.000000      -0.082263      -0.031397       0.020967
# 25%    124656.500000       0.343078       0.319170       0.344096
# 50%    249738.500000       0.484005       0.553209       0.551471
# 75%    374836.250000       0.643789       0.731263       0.648315
# max    499999.000000       1.016227       0.859697       1.006955
#
#                cont4          cont5          cont6          cont7  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.515683       0.502022       0.526515       0.487890
# std         0.233035       0.220701       0.217909       0.181096
# min         0.152761       0.276377       0.066166      -0.097666
# ...

# %%
X=df.iloc[:,1:-1]
y= df.target

# %% [markdown]
# # plotting the data

# %%
for i in range(14):
    sns.distplot(X.iloc[:,i])
    plt.show()

# %%
sns.distplot(y)

# %% [markdown]
# **My Observations**
# * No feature properly defines a normal curve which may be beneficial for some algorithms; hence scaling may be required.
# * In cont5 and the target feature some outliers may be present.

# %% [markdown]
# Lets zoom into the extremes edges of the data where outllier may be located

# %%
sns.distplot(y[y<5])

# %%
sns.distplot(X.cont5[X.cont5<0.5])

# %% [markdown]
# My observation
# * We have to take care of this outliers either by proper scaling or removing them

# %% [markdown]
# # Plotting some scatterplots and Correlation

# %%
#sns.pairplot(X.iloc[:,0:6])

# %%
corr = df.iloc[:,1:].corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# <style  type="text/css" >
# #T_58a6bfae_51e0_11eb_98cf_0242ac130202row0_col0,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row1_col1,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row2_col2,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row3_col3,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row4_col4,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row5_col5,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row6_col6,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row7_col7,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row8_col8,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row9_col9,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row10_col10,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row11_col11,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row12_col12,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row13_col13,#T_58a6bfae_51e0_11eb_98cf_0242ac130202row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# My observations
# * There are some features like cont12 and cont11 with high correlation.
# * Not so much correlation of the features with the target.
# * May be some feature enginnering and creating some strong features may help.
# * from the scatterplots not so much can be concluded.

# %% [markdown]
# # plotting scatterplots between features and targets

# %%
for i in range(14):
    sns.scatterplot(X.iloc[:,i],y)
    plt.show()

# %% [markdown]
# # plotting the test data

# %%
df_test = pd.read_csv("../input/tabular-playground-series-jan-2021/test.csv")
df_test.head()
# Out:
#    id     cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0   0  0.353600  0.738780  0.600939  0.293377  0.285691  0.458006  0.620704
# 1   2  0.907222  0.189756  0.215531  0.869915  0.301333  0.528958  0.390351
# 2   6  0.179287  0.355353  0.623972  0.437812  0.282476  0.320826  0.386789
# 3   7  0.359385  0.181049  0.551368  0.206386  0.280763  0.482076  0.506677
# 4  10  0.335791  0.682607  0.676481  0.219465  0.282861  0.581721  0.748639
#
#       cont8     cont9    cont10    cont11    cont12    cont13    cont14
# 0  0.422249  0.369203  0.435727  0.550540  0.699134  0.286864  0.364515
# 1  0.521112  0.794779  0.798580  0.446475  0.449037  0.916964  0.513002
# 2  0.776422  0.222268  0.229102  0.211913  0.222651  0.327164  0.827941
# 3  0.362793  0.379737  0.345686  0.445276  0.518485  0.299028  0.598166
# 4  0.350158  0.448915  0.506878  0.817721  0.805895  0.790591  0.249275

# %%
X_test=df.iloc[:,1:]
for i in range(14):
    sns.distplot(X_test.iloc[:,i])
    plt.show()

# %% [markdown]
# My observations
# * The test and train distribution is almost same.
# * Since we predicting on almost same type of data,for validation using KFOlDS with some random split may work.

# %% [markdown]
# # transforming and making the data "normal" using quantile_transformer

# %%
from sklearn.preprocessing import QuantileTransformer

# %%
quantile = QuantileTransformer(output_distribution='normal')
data_trans = quantile.fit_transform(X)

# %%
data_trans = pd.DataFrame(data_trans)

# %%
for i in range(14):
    sns.distplot(data_trans.iloc[:,i])
    plt.show()

# %% [markdown]
# # To be continued

# %% [markdown]
# #say_my_name
